# %% [markdown]
# # Computations

# %% [markdown]
# ## Calculate Galactic Coordinates

# %%
import math

# 61 Cygni			082.31976 -05.81813   11.4

stars = [
    { "name": "Beta Lyrae", "position": [063.1876092196076, +14.7834598281456, 960]},
    { "name": "Antares", "position": [351.94713737, +15.06432170, 550]},
    { "name": "Betelgeuse", "position": [199.78723619, -08.95860329, 548]},
    { "name": "61 Cygni", "position": [082.31976, -05.81813, 11.4]},
    { "name": "Iota Horologii", "position": [268.8095911002851, -58.3236241204180, 56.5]},
    { "name": "LHS 2520", "position": [288.3203477427180, +46.6240527948787, 40]},
    { "name": "61 Ursae Majoris", "position": [183.5495205833530, +73.3246340996153, 31.2]},
    { "name": "Epsilon Indi", "position": [336.1926307305795, -48.0448608239800, 12]},
    { "name": "Aldebaran", "position": [180.97191142, -20.24829666, 67]},
    { "name": "Algol", "position": [148.9765258648, -14.9002614291, 94]},
    { "name": "Kepler-22", "position": [079.0918643265914, +15.7922760689013, 644]},

]

for star in stars:
    x = star["position"][2] * math.cos(math.radians(star["position"][1])) * math.cos(math.radians(star["position"][0]))
    z = - star["position"][2] * math.cos(math.radians(star["position"][1])) * math.sin(math.radians(star["position"][0]))
    y = - star["position"][2] * math.sin(math.radians(star["position"][1]))
    star["pos_absolute"] = [round(x, 2), round(y, 2), round(z, 2)]

for star in stars:
    print(f"{star['name'].title()}: {star['pos_absolute']}")
# Out:
# Beta Lyrae: [418.69, -244.96, -828.43]
# Antares: [525.86, -142.95, 74.4]
# Betelgeuse: [-509.35, 85.34, 183.25]
# 61 Cygni: [1.52, 1.16, -11.24]
# Iota Horologii: [-0.62, 48.08, 29.66]
# Lhs 2520: [8.64, -29.07, 26.08]
# 61 Ursae Majoris: [-8.94, -29.89, 0.55]
# Epsilon Indi: [7.34, 8.92, 3.24]
# Aldebaran: [-62.85, 23.19, 1.07]
# Algol: [-77.85, 24.17, -46.82]
# Kepler-22: [117.27, -175.26, -608.5]

# %%
old_stars = [
    { "name": "vega", "position": [67.5, 19.2, 25]},
    { "name": "alpha centauri", "position": [315.8, -0.7, 4]},
    { "name": "sirius", "position": [227.2, -8.9, 9]},
    { "name": "tau ceti", "position": [173.1, -73.4, 12]},
    { "name": "procyon", "position": [213.7, 13.0, 11]},
    { "name": "40 Eridani", "position": [200.8, -38.0, 16.3]},
    { "name": "Wolf 359", "position": [244.1, 56.1, 7.8]},
    { "name": "Omega Leonis", "position": [223.66, 38.90, 108]},
    { "name": "Canopus", "position": [261.21210208, -25.29220544, 310]},
    { "name": "Capella", "position": [162.58847600, 04.56643053, 42.9]},
    { "name": "Delta Pavonis", "position": [329.7673520576934, -32.4164645155008, 19.89]},
    { "name": "36 Ophiuchi", "position": [358.2788979988, 06.8780379683, 19.5]},
    { "name": "Gliese 581", "position": [354.0776257523032, 40.0186970087399, 20.5]},
    { "name": "Alpha Cassiopeiae", "position": [121.4164062796607, -06.3022507244394, 228]},
    { "name": "Arcturus", "position": [015.05005923, +69.11129459, 36.7]},
    { "name": "Rigel", "position": [209.24118506, -25.24534825, 850]},
    { "name": "Achernar", "position": [290.84124169, -58.79200969, 139]},
    { "name": "Regulus", "position": [226.42735281, +48.93420887, 79]},
    { "name": "Fomalhaut", "position": [020.48814538, -64.90960178, 25]},
    { "name": "Barnard's Star", "position": [031.0087027177046, +14.0626510150033, 5.96]},
    { "name": "Altair", "position": [047.74412569, -08.90918816, 16.7]},
    { "name": "Acrux", "position": [300.12657738, -00.36272479, 321]},
    { "name": "Zeta Reticuli", "position": [279.0961935830915, -47.2141042298922, 39.3]},
    { "name": "Deneb", "position": [084.28473664, +01.99754611, 2600]},
    { "name": "70 Ophiuchi", "position": [029.89344216, +11.36699835, 16.7]},
    { "name": "Sigma Draconis", "position": [101.3033259307169, +21.8769554079307, 18.8]},
    { "name": "Luyten's Star", "position": [212.3445627523984, +10.3735144475450, 12.35]},
    { "name": "Eta Ophiuchi", "position": [006.72144052, +14.00783433, 88]},
    { "name": "Epsilon Ophiuchi", "position": [008.5658896040841, +30.8098055120716, 106.4]},
    { "name": "Gamma Piscium", "position": [082.4825259337995, -52.0273517030784, 135]},
    { "name": "Alpha Piscium", "position": [155.35101848, -55.59958038, 151]},
    { "name": "Epsilon Eridani", "position": [195.8446406895699, -48.0512999525119, 10.5]},
    { "name": "Theta Eridani", "position": [247.8556448188, -60.7363000017, 165]},
    { "name": "Iota Leporis", "position": [212.6728511314869, -27.3162862446595, 232]},
    { "name": "Beta Tauri", "position": [177.99440340, -03.74540398, 134]},
    { "name": "Theta Leonis", "position": [235.3722262209602, +64.5849655488291, 165]},
    { "name": "Theta Arietis", "position": [149.2703555551716, -38.4967240659437, 452]},
    { "name": "52 Cygni", "position": [073.3049144534971, -07.6314087959501, 291]},
    { "name": "Psi1 Draconis", "position": [102.9730, +31.0296, 75]},
    { "name": "Beta Lyrae", "position": [063.1876092196076, +14.7834598281456, 960]},
    { "name": "Antares", "position": [351.94713737, +15.06432170, 550]},
]

for star in old_stars:
    x = star["position"][2] * math.cos(math.radians(star["position"][1])) * math.cos(math.radians(star["position"][0]))
    z = - star["position"][2] * math.cos(math.radians(star["position"][1])) * math.sin(math.radians(star["position"][0]))
    y = - star["position"][2] * math.sin(math.radians(star["position"][1]))
    star["pos_absolute"] = [round(x, 2), round(y, 2), round(z, 2)]

# %%
def calculate_distance(star1, star2):
    x1, y1, z1 = star1["pos_absolute"]
    x2, y2, z2 = star2["pos_absolute"]
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2 + (z2 - z1)**2)

star_a = old_stars[10]
star_b = old_stars[25] 
distance = calculate_distance(star_a, star_b)
print(f"Distance between {star_a['name'].title()} and {star_b['name'].title()}: {distance} light years")
# Out:
# Distance between Delta Pavonis and Sigma Draconis: 35.87516411112289 light years
