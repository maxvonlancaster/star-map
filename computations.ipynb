# %% [markdown]
# # Computations

# %% [markdown]
# ## Calculate Galactic Coordinates

# %%
import math

# 213.7 +13.0 11

stars = [
    { "name": "vega", "position": [67.5, 19.2, 25]},
    { "name": "alpha centauri", "position": [315.8, -0.7, 4]},
    { "name": "sirius", "position": [227.2, -8.9, 9]},
    { "name": "tau ceti", "position": [173.1, -73.4, 12]},
    { "name": "procyon", "position": [213.7, 13.0, 11]},
    { "name": "40 Eridani", "position": [200.8, -38.0, 16.3]},
]

for star in stars:
    x = star["position"][2] * math.cos(math.radians(star["position"][1])) * math.cos(math.radians(star["position"][0]))
    z = star["position"][2] * math.cos(math.radians(star["position"][1])) * math.sin(math.radians(star["position"][0]))
    y = star["position"][2] * math.sin(math.radians(star["position"][1]))
    star["pos_absolute"] = [x, y, z]

for star in stars:
    print(f"{star['name'].title()}: {star['pos_absolute']}")
# Out:
# Vega: [9.034929770174104, 8.22166616846458, 21.812249986242747]
# Alpha Centauri: [2.8674284174736324, -0.048868003340988675, -2.7884522927448705]
# Sirius: [-6.04134665780748, -1.3923934766952129, -6.524060926007282]
# Tau Ceti: [-3.403430690941493, -11.4998708935816, 0.4118603682223777]
# Procyon: [-8.91694311066484, 2.474461597782515, -5.946861807900569]
# 40 Eridani: [-12.007438777688112, -10.03528204780823, -4.561198112449147]

# %%
for i in range(30, 1500, 10):
    print(math.exp(100 / i))
# Out:
# 28.03162489452614
# 12.182493960703473
# 7.38905609893065
# 5.29449005047003
# 4.172733883598096
# 3.4903429574618414
# 3.037731777517483
# 2.718281828459045
# 2.482065084623012
# 2.300975890892825
# 2.158105533948446
# 2.042727070266142
# 1.9477340410546757
# 1.8682459574322223
# 1.8008077137563978
# 1.7429089986334578
# 1.692684600326856
# 1.6487212707001282
# 1.6099296400199838
# 1.5754571033903182
# 1.544627233920827
# 1.5168967963882134
# 1.4918246976412703
# 1.4690491938490167
# 1.4482709119769421
# 1.4292400324179777
# 1.4117464941153497
# 1.3956124250860895
# 1.3806862320338231
# 1.3668379411737963
# 1.3539554927749704
# 1.3419417698828804
# 1.33071219744735
# 1.3201927884341202
# 1.3103185430275461
# 1.3010321288603353
# 1.2922827864993338
# 1.2840254166877414
# 1.2762198151653752
# 1.2688300280258125
# 1.2618238060756062
# 1.2551721409393686
# 1.2488488690016821
# 1.2428303319121348
# 1.2370950844673394
# 1.2316236423470497
# 1.2263982635139905
# 1.2214027581601699
# ...
